# %%
# %run your_algorithm.py
# Out:
# Adaboost
# -------
# fitting: 2.32398104668
# predicting: 0.0671329498291
# 0.912
# Random Forest
# -------
# fitting: 0.0507729053497
# predicting: 0.00179481506348
# 0.932
