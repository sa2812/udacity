# %%
# %run enron_outliers.py

# %%
for item in data_dict:
    try:
        if int(data_dict[item]['bonus']) > 5e6 and int(data_dict[item]['salary']) > 1e6:
            print item
    except ValueError:
        pass
# Out:
# LAY KENNETH L
# SKILLING JEFFREY K
